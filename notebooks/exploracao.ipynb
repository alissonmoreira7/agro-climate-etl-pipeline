# %%
import requests
from config.settings import API_KEY, CIDADE_TESTE, BASE_URL


parametros = {
    "q": CIDADE_TESTE,
    "appid": API_KEY,
    "units": "metric"
}

response = requests.get(BASE_URL, params=parametros)

if response.status_code == 200:
    dados = response.json()
    print("Conexão bem-sucedida! Dados brutos bem recebidos.")

else:
    print(f"Erro na conexão! Status Code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import requests
# ----> 2 from config.settings import API_KEY, CIDADE_TESTE, BASE_URL
#       5 parametros = {
#       6     "q": CIDADE_TESTE,
#       7     "appid": API_KEY,
#       8     "units": "metric"
#       9 }
#      11 response = requests.get(BASE_URL, params=parametros)
#
# ModuleNotFoundError: No module named 'config'
